# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# tripdata = pd.read_csv('yellow_tripdata_2024-01_cleaned1.csv')
# tripdata

# %%
tripdata['tip_perc'] = tripdata['tip_amount']/tripdata['fare_amount']
tripdata
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...           ...                  ...                   ...              ...
# 2785522         2  2024-01-31 23:10:28   2024-01-31 23:18:30              1.0
# 2785523         2  2024-01-31 23:01:04   2024-01-31 23:17:35              1.0
# 2785524         1  2024-01-31 23:08:13   2024-01-31 23:25:00              3.0
# 2785525         1  2024-01-31 23:49:46   2024-01-31 23:53:10              0.0
# 2785526         2  2024-01-31 23:03:26   2024-01-31 23:09:12              1.0
#
# ...

# %%
tripdata = tripdata[tripdata['trip_distance'] < 20]
tripdata
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...           ...                  ...                   ...              ...
# 2785522         2  2024-01-31 23:10:28   2024-01-31 23:18:30              1.0
# 2785523         2  2024-01-31 23:01:04   2024-01-31 23:17:35              1.0
# 2785524         1  2024-01-31 23:08:13   2024-01-31 23:25:00              3.0
# 2785525         1  2024-01-31 23:49:46   2024-01-31 23:53:10              0.0
# 2785526         2  2024-01-31 23:03:26   2024-01-31 23:09:12              1.0
#
# ...

# %%
tripdata['trip_duration'] = pd.to_timedelta(tripdata['trip_duration'])
tripdata['trip_duration_sec'] = tripdata['trip_duration'].dt.total_seconds()
tripdata
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...           ...                  ...                   ...              ...
# 2785522         2  2024-01-31 23:10:28   2024-01-31 23:18:30              1.0
# 2785523         2  2024-01-31 23:01:04   2024-01-31 23:17:35              1.0
# 2785524         1  2024-01-31 23:08:13   2024-01-31 23:25:00              3.0
# 2785525         1  2024-01-31 23:49:46   2024-01-31 23:53:10              0.0
# 2785526         2  2024-01-31 23:03:26   2024-01-31 23:09:12              1.0
#
# ...

# %%
tripdata['additional_charges'] = tripdata['total_amount'] - tripdata['fare_amount'] - tripdata['tip_amount']
tripdata
# Out:
# C:\Users\nihum\AppData\Local\Temp\ipykernel_63480\3108003468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tripdata['additional_charges'] = tripdata['total_amount'] - tripdata['fare_amount'] - tripdata['tip_amount']
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...

# %%
# tripdata['tripdate_dd'] = [int(ele.split(' ')[0].split('-')[2]) for ele in tripdata['tpep_pickup_datetime']]
# weatherdata = pd.read_csv('JanWeatherData.csv').set_index('JanDate')
# tripdata = tripdata.join(weatherdata,on='tripdate_dd')
# taxizones = pd.read_csv('taxi_zone_lookup.csv').drop(columns = ['Borough','Zone','service_zone','median_income','percpoverty','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12']).set_index('LocationID')
# tripdata = tripdata.join(taxizones,on = 'PULocationID')
tripdata['average_income'] = [int(ele.strip('$').replace(',','')) for ele in tripdata['average_income']]
tripdata
# Out:
# C:\Users\nihum\AppData\Local\Temp\ipykernel_63480\2517101014.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tripdata['average_income'] = [int(ele.strip('$').replace(',','')) for ele in tripdata['average_income']]
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...

# %%
ax = tripdata.plot.scatter(x='tip_perc',y='AvgTemp')
ax.set_xlabel('Tip ratio')
ax.set_ylabel('Daily Average Temperature')
ax
# Out:
# <Axes: xlabel='Tip ratio', ylabel='Daily Average Temperature'>

# %%
ax2 = tripdata.boxplot(column=['tip_perc'],by='payment_type')
ax2.set_xlabel('Payment Type')
ax2.set_ylabel('Tip Ratio')
# plt.xticks([])
plt.show()

# %%
# tripdata_final = tripdata_final.rename(columns = {'tip_perc':'tip_ratio','AvgTemp':'DailyAvgTemp','AvgHumidity':'DailyAvgHumidity','AvgHumidity':'DailyAvgHumidity','Precipitation':'DailyPrecipitation','average_income':'avg_income_borough'})
tripdata_final.drop(columns = ['tpep_pickup_datetime','tpep_dropoff_datetime']).corr().to_csv('trips_corrplot.csv')
